# %%
from matplotlib import pyplot as plt

both_reduced = True

# %%
# Run where only 4 is reduced

if not both_reduced:
    times = {
        '2a': 0.890884000000,
        '2b': 2.153624000000,
        '2c': 900, # 1747.177659 or TLE
        '2d': 900, # 1851.849467 or TLE
        '2e': 717.196058000000,
        '2f1': 2.622502000000,
        '2f2': 699.299431000000,
        '2g1': 5.288033000000,
        '2g2': 0, # Get stuck sadly
        '4a': 0.618432000000,
        '4b': 0.145287000000,
        '4c': 371.952780000000,
        '4d': 364.517514000000,
        '4e': 121.422184000000,
        '4f1': 6.272916000000,
        '4f2': 150.084366000000,
        '4g1': 6.591691000000,
        '4g2': 0, # Get stuck sadly
    }

    norms = {
        '2a': 21678226.356345690787,
        '2b': 21678226.356345690787,
        '2c': 0, # TLE
        '2d': 0, # TLE
        '2e': 21678226.356345690787,
        '2f1': 21678226.356345690787,
        '2f2': 21678226.356345690787,
        '2g1': 21678226.356345690787,
        '2g2': 0, # Get stuck sadly
        '4a': 42486.584789395558,
        '4b': 42486.584789395558,
        '4c': 42486.584789395558,
        '4d': 42486.584789395558,
        '4e': 42486.584789395558,
        '4f1': 42486.584789395558,
        '4f2': 42486.584789395558,
        '4g1': 42486.584789395558,
        '4g2': 0, # Get stuck sadly
    }

    diffs = {
        '2a': 0.000000005752,
        '2b': 0.000000000000,
        '2c': 0, # TLE
        '2d': 0, # TLE
        '2e': 0.000002913663,
        '2f1': 869.712054685470,
        '2f2': 869.712054307089,
        '2g1': 0.000000005752,
        '2g2': 0, # Get stuck sadly
        '4a': 0.000000000000,
        '4b': 0.000000000000,
        '4c': 0.000000000000,
        '4d': 0.000000000000,
        '4e': 0.000000,
        '4f1': 2549.195087363727,
        '4f2': 849.731695787908,
        '4g1': 0.000000000000,
        '4g2': 0, # Get stuck sadly
    }

# %%
# Run where both are reduced

if both_reduced:
    times = {
        '2a': 0.418765000000,
        '2b': 0.400951000000,
        '2c': 208.807028000000,
        '2d': 188.293802000000,
        '2e': 89.301954000000,
        '2f1': 0.715744000000,
        '2f2': 90.120550000000,
        '2g1': 3.396225000000,
        '2g2': 0, # Get stuck sadly
        '4a': 0.666675000000,
        '4b': 0.776541000000,
        '4c': 656.653535000000,
        '4d': 599.460566000000,
        '4e': 190.843278000000,
        '4f1': 16.295606000000,
        '4f2': 291.952148000000,
        '4g1': 0, # Get stuck sadly
        '4g2': 0, # Get stuck sadly #
    }

    norms = {
        '2a': 5419556.589086441323,
        '2b': 5419556.589086441323,
        '2c': 5419556.589086269960,
        '2d': 5419556.589086269960,
        '2e': 5419556.589086269960,
        '2f1': 5419557.757233955897,
        '2f2': 5419557.757233940065,
        '2g1': 5419556.589086442254,
        '2g2': 0, # Get stuck sadly
        '4a': 42486.584789395558,
        '4b': 42486.584789395558,
        '4c': 42486.584789395558,
        '4d': 42486.584789395558,
        '4e': 42486.584789395558,
        '4f1': 45035.779876759312,
        '4f2': 42486.584789395558,
        '4g1': 0, # Get stuck sadly
        '4g2': 0, # Get stuck sadly
    }

    diffs = {
        '2a': 0,
        '2b': 0,
        '2c': 0.000000174623,
        '2d': 0.000000174623,
        '2e': 0.000000174623,
        '2f1': 1.168147522549,
        '2f2': 1.168147494354,
        '2g1': 0.000000000546,
        '2g2': 0, # Get stuck sadly #
        '4a': 0.000000000000,
        '4b': 0.000000000000,
        '4c': 0.000000000000,
        '4d': 0.000000000000,
        '4e': 0.000000000000,
        '4f1': 2549.195087363727,
        '4f2': 0.000000000000,
        '4g1': 0, # Get stuck sadly
        '4g2': 0, # Get stuck sadly
    }

# %%
# Make barchart of times
plt.figure()

plt.bar(times.keys(), times.values())

plt.xlabel('Problem')
plt.ylabel('Time (s)')

plt.title('Time taken to solve each problem')

plt.show()

# Show on logaritmic scale
plt.figure()
plt.bar(times.keys(), times.values())

plt.yscale('log')

plt.xlabel('Problem')
plt.ylabel('Time (s)')

plt.title('Time taken to solve each problem, log scale')

plt.show()

# %%
# Make barchart of Norms
plt.figure()

plt.bar(norms.keys(), norms.values())

plt.xlabel('Problem')
plt.ylabel('Norm')

plt.title('Norm of the difference between the computed solution and the true solution')

plt.show()

# Show on logaritmic scale
plt.figure()
plt.bar(norms.keys(), norms.values())

plt.yscale('log')

plt.xlabel('Problem')
plt.ylabel('Norm')

plt.title('Norm of the difference between the computed solution and the true solution, log scale')

plt.show()

# %%
# Make barchart of Diffs
plt.figure()

plt.bar(diffs.keys(), diffs.values())

plt.xlabel('Problem')
plt.ylabel('Difference in norm')

plt.title('Difference in norm between the computed solution and the (probably) true solution')

plt.show()

# Show on logaritmic scale
plt.figure()
plt.bar(diffs.keys(), diffs.values())

plt.yscale('log')

plt.xlabel('Problem')
plt.ylabel('Difference in norm')

plt.title('Difference in norm between the computed solution and the (probably) true solution, log scale')

plt.show()
